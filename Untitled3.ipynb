# %%
# !ls -F
# Out:
# sample_data/

# %%
# !pip install prophet pandas matplotlib seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from prophet import Prophet

# %%
data = """Date,Sales
2022-01-01,120
2022-01-02,135
2022-01-03,128
2022-01-04,140
2022-01-05,150
2022-01-06,160
2022-01-07,170
2022-01-08,165
2022-01-09,175
2022-01-10,180
2022-01-11,190
2022-01-12,200
2022-01-13,210
2022-01-14,215
2022-01-15,220
2022-01-16,230
2022-01-17,240
2022-01-18,245
2022-01-19,250
2022-01-20,260
2022-01-21,270
2022-01-22,280
2022-01-23,275
2022-01-24,290
2022-01-25,300
2022-01-26,310
2022-01-27,320
2022-01-28,325
2022-01-29,330
2022-01-30,340
2022-01-31,350
2022-02-01,355
2022-02-02,360
2022-02-03,370
2022-02-04,380
2022-02-05,390
2022-02-06,395
2022-02-07,405
2022-02-08,410
2022-02-09,420
2022-02-10,430
2022-02-11,440
2022-02-12,445
2022-02-13,455
2022-02-14,460
2022-02-15,470
2022-02-16,475
2022-02-17,485
2022-02-18,490
2022-02-19,500
2022-02-20,510
2022-02-21,520
2022-02-22,525
2022-02-23,530
2022-02-24,540
2022-02-25,550
2022-02-26,560
2022-02-27,565
2022-02-28,570
"""

with open("sales_data.csv", "w") as file:
    file.write(data)

df = pd.read_csv("sales_data.csv")
df.head()
# Out:
#          Date  Sales
# 0  2022-01-01    120
# 1  2022-01-02    135
# 2  2022-01-03    128
# 3  2022-01-04    140
# 4  2022-01-05    150

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values('Date')
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    59 non-null     datetime64[ns]
#  1   Sales   59 non-null     int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 1.1 KB

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='Date', y='Sales', data=df, marker="o")
plt.title("📈 Sales Trend Over Time")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
data = df.rename(columns={'Date': 'ds', 'Sales': 'y'})
data.head()
# Out:
#           ds    y
# 0 2022-01-01  120
# 1 2022-01-02  135
# 2 2022-01-03  128
# 3 2022-01-04  140
# 4 2022-01-05  150

# %%
model = Prophet()
model.fit(data)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = model.make_future_dataframe(periods=90)
forecast = model.predict(future)
forecast[['ds','yhat']].tail()
# Out:
#             ds         yhat
# 144 2022-05-25  1262.887758
# 145 2022-05-26  1273.109433
# 146 2022-05-27  1281.455243
# 147 2022-05-28  1287.774300
# 148 2022-05-29  1295.870662

# %%
model.plot(forecast)
plt.title("🔮 Sales Forecast for 90 Days")
plt.xlabel("Date")
plt.ylabel("Predicted Sales")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128302 (\N{CRYSTAL BALL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
model.plot_components(forecast)
plt.show()

# %% [markdown]
# # FUTURE_ML_01_sales_Forecast
